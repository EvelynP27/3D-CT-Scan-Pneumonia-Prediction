# %%
import os
import zipfile
import numpy as np
import tensorflow as tf  # for data preprocessing

import keras
from keras import layers

url = "https://github.com/hasibzunair/3D-image-classification-tutorial/releases/download/v0.2/CT-0.zip"
filename = os.path.join(os.getcwd(), "CT-0.zip")
keras.utils.get_file(filename, url)

url = "https://github.com/hasibzunair/3D-image-classification-tutorial/releases/download/v0.2/CT-23.zip"
filename = os.path.join(os.getcwd(), "CT-23.zip")
keras.utils.get_file(filename, url)
# Out:
# Downloading data from https://github.com/hasibzunair/3D-image-classification-tutorial/releases/download/v0.2/CT-0.zip
# 1065471431/1065471431 [==============================] - 7s 0us/step
# Downloading data from https://github.com/hasibzunair/3D-image-classification-tutorial/releases/download/v0.2/CT-23.zip
# 1045162547/1045162547 [==============================] - 10s 0us/step
# '/content/CT-23.zip'

# %%
# !unzip "CT-0.zip"
# !unzip "CT-23.zip"
# Out:
# Archive:  CT-0.zip
#    creating: CT-0/
#   inflating: CT-0/study_0001.nii.gz
#   inflating: CT-0/study_0002.nii.gz
#   inflating: CT-0/study_0003.nii.gz
#   inflating: CT-0/study_0004.nii.gz
#   inflating: CT-0/study_0005.nii.gz
#   inflating: CT-0/study_0006.nii.gz
#   inflating: CT-0/study_0007.nii.gz
#   inflating: CT-0/study_0008.nii.gz
#   inflating: CT-0/study_0009.nii.gz
#   inflating: CT-0/study_0010.nii.gz
#   inflating: CT-0/study_0011.nii.gz
#   inflating: CT-0/study_0012.nii.gz
#   inflating: CT-0/study_0013.nii.gz
#   inflating: CT-0/study_0014.nii.gz
#   inflating: CT-0/study_0015.nii.gz
#   inflating: CT-0/study_0016.nii.gz
#   inflating: CT-0/study_0017.nii.gz
#   inflating: CT-0/study_0018.nii.gz
#   inflating: CT-0/study_0019.nii.gz
#   inflating: CT-0/study_0020.nii.gz
#   inflating: CT-0/study_0021.nii.gz
#   inflating: CT-0/study_0022.nii.gz
#   inflating: CT-0/study_0023.nii.gz
#   inflating: CT-0/study_0024.nii.gz
#   inflating: CT-0/study_0025.nii.gz
#   inflating: CT-0/study_0026.nii.gz
#   inflating: CT-0/study_0027.nii.gz
#   inflating: CT-0/study_0028.nii.gz
#   inflating: CT-0/study_0029.nii.gz
#   inflating: CT-0/study_0030.nii.gz
#   inflating: CT-0/study_0031.nii.gz
#   inflating: CT-0/study_0032.nii.gz
#   inflating: CT-0/study_0033.nii.gz
#   inflating: CT-0/study_0034.nii.gz
#   inflating: CT-0/study_0035.nii.gz
#   inflating: CT-0/study_0036.nii.gz
#   inflating: CT-0/study_0037.nii.gz
#   inflating: CT-0/study_0038.nii.gz
#   inflating: CT-0/study_0039.nii.gz
#   inflating: CT-0/study_0040.nii.gz
#   inflating: CT-0/study_0041.nii.gz
#   inflating: CT-0/study_0042.nii.gz
#   inflating: CT-0/study_0043.nii.gz
#   inflating: CT-0/study_0044.nii.gz
#   inflating: CT-0/study_0045.nii.gz
#   inflating: CT-0/study_0046.nii.gz
#   inflating: CT-0/study_0047.nii.gz
#   inflating: CT-0/study_0048.nii.gz
#   inflating: CT-0/study_0049.nii.gz
#   inflating: CT-0/study_0050.nii.gz
#   inflating: CT-0/study_0051.nii.gz
#   inflating: CT-0/study_0052.nii.gz
#   inflating: CT-0/study_0053.nii.gz
#   inflating: CT-0/study_0054.nii.gz
#   inflating: CT-0/study_0055.nii.gz
#   inflating: CT-0/study_0056.nii.gz
#   inflating: CT-0/study_0057.nii.gz
#   inflating: CT-0/study_0058.nii.gz
#   inflating: CT-23/study_1098.nii.gz
#   inflating: CT-23/study_1099.nii.gz
#   inflating: CT-23/study_1100.nii.gz
#   inflating: CT-23/study_1101.nii.gz
#   inflating: CT-23/study_1102.nii.gz
#   inflating: CT-23/study_1103.nii.gz
#   inflating: CT-23/study_1104.nii.gz
#   inflating: CT-23/study_1105.nii.gz
#   inflating: CT-23/study_1106.nii.gz
#   inflating: CT-23/study_1107.nii.gz
#   inflating: CT-23/study_1108.nii.gz

# %% [markdown]
# Loading Data and Preprocessing (scale HU values, resize width/height/depth, rotate volumes)

# %%
import nibabel as nib
from scipy import ndimage

def read_nifti_file(filepath):
  """Read and load volume"""
  # Read file
  scan = nib.load(filepath)
  # Get raw data
  scan = scan.get_fdata()
  return scan

def normalize(volume):
  """Normalize the volume"""
  min = -1000
  max = 400
  volume[volume < min] = min
  volume[volume > max] = max
  volume = (volume - min) / (max-min)
  volume = volume.astype("float32")
  return volume

def resize_volume(img):
  """Resize across z-axis"""
  # Set the desired depth (get to crop)
  desired_depth = 64
  desired_width = 128
  desired_height = 128
  # Get current depth
  current_depth = img.shape[-1]
  current_width = img.shape[0]
  current_height = img.shape[1]
  # Compute depth factor
  depth = current_depth / desired_depth
  width = current_width / desired_width
  height = current_height / desired_height
  depth_factor = 1 / depth
  width_factor = 1 / width
  height_factor = 1/ height
  # Rotate
  img = ndimage.rotate(img, 90, reshape=False)
  # Resize across z-axis
  img = ndimage.zoom(img, (width_factor, height_factor, depth_factor), order=1)
  return img

def process_scan(path):
  """Read and resize volume"""
  # Read scan
  volume = read_nifti_file(path)
  # Normalize
  volume = normalize(volume)
  # Resize width, height and depth
  volume = resize_volume(volume)
  return volume

# %%
# Folder "CT-0" consist of CT scans having normal lung tissue,
# no CT-signs of viral pneumonia.
normal_scan_paths = [
    os.path.join(os.getcwd(), "CT-0", x)
    for x in os.listdir("CT-0")
]

# Folder "CT-23" consist of CT scans having several ground-glass opacifications,
# involvement of lung parenchyma.
abnormal_scan_paths = [
    os.path.join(os.getcwd(), "CT-23", x)
    for x in os.listdir("CT-23")
]

print("CT scans with normal lung tissue: " + str(len(normal_scan_paths)))
print("CT scans with abnormal lung tissue: " + str(len(abnormal_scan_paths)))
# Out:
# CT scans with normal lung tissue: 100
# CT scans with abnormal lung tissue: 100

# %% [markdown]
# Build, Train, and Validation Datasets (resize scans, 1=abnormal and 0=normal, 70-30 for training/validation)

# %%
# Read and process the scans.
# Each scan is resized across height, width, and depth and rescaled.
abnormal_scans = np.array([process_scan(path) for path in abnormal_scan_paths])
normal_scans = np.array([process_scan(path) for path in normal_scan_paths])


# For the CT scans having presence of viral pneumonia
# assign 1, for the normal ones assign 0.
abnormal_labels = np.array([1 for _ in range(len(abnormal_scans))])
normal_labels = np.array([0 for _ in range(len(normal_scans))])

# %%
from sklearn.model_selection import train_test_split

all_scans = np.concatenate((abnormal_scans, normal_scans), axis=0)
all_labels = np.concatenate((abnormal_labels, normal_labels), axis=0)


# Split data in the ratio 70-30 for training and validation.
x_train, x_val, y_train, y_val = train_test_split(all_scans, all_labels, test_size=0.3, stratify=all_labels, random_state=42)

print(
    f"Number of samples in train and validation are {x_train.shape[0]} and {x_val.shape[0]}."
)
# Out:
# Number of samples in train and validation are 140 and 60.

# %% [markdown]
# Data Augmentation

# %%
import random

from scipy import ndimage


def rotate(volume):
    """Rotate the volume by a few degrees"""

    def scipy_rotate(volume):
        # define some rotation angles
        angles = [-20, -10, -5, 5, 10, 20]
        # pick angles at random
        angle = random.choice(angles)
        # rotate volume
        volume = ndimage.rotate(volume, angle, reshape=False)
        volume[volume < 0] = 0
        volume[volume > 1] = 1
        return volume

    augmented_volume = tf.numpy_function(scipy_rotate, [volume], tf.float32)
    return augmented_volume


def train_preprocessing(volume, label):
    """Process training data by rotating and adding a channel."""
    # Rotate volume
    volume = rotate(volume)
    volume = tf.expand_dims(volume, axis=3)
    return volume, label


def validation_preprocessing(volume, label):
    """Process validation data by only adding a channel."""
    volume = tf.expand_dims(volume, axis=3)
    return volume, label

# %%
train_loader = tf.data.Dataset.from_tensor_slices((x_train, y_train))
validation_loader = tf.data.Dataset.from_tensor_slices((x_val, y_val))

batch_size = 2
# Augment the on the fly during training.
train_dataset = (
    train_loader.shuffle(len(x_train))
    .map(train_preprocessing)
    .batch(batch_size)
    .prefetch(2)
)
# Only rescale.
validation_dataset = (
    validation_loader.shuffle(len(x_val))
    .map(validation_preprocessing)
    .batch(batch_size)
    .prefetch(2)
)

# %%
import matplotlib.pyplot as plt

data = train_dataset.take(1)
images, labels = list(data)[0]
images = images.numpy()
image = images[0]

def plot_slices(num_rows, num_columns, width, height, data):
    """Plot a montage of 20 CT slices"""
    data = np.rot90(np.array(data))
    data = np.transpose(data)
    data = np.reshape(data, (num_rows, num_columns, width, height))
    rows_data, columns_data = data.shape[0], data.shape[1]
    heights = [slc[0].shape[0] for slc in data]
    widths = [slc.shape[1] for slc in data[0]]
    fig_width = 12.0
    fig_height = fig_width * sum(heights) / sum(widths)
    f, axarr = plt.subplots(
        rows_data,
        columns_data,
        figsize=(fig_width, fig_height),
        gridspec_kw={"height_ratios": heights},
    )
    for i in range(rows_data):
        for j in range(columns_data):
            axarr[i, j].imshow(data[i][j], cmap="gray")
            axarr[i, j].axis("off")
    plt.subplots_adjust(wspace=0, hspace=0, left=0, right=1, bottom=0, top=1)
    plt.show()


# Visualize montage of slices.
# 4 rows and 10 columns for 100 slices of the CT scan.
plot_slices(4, 10, 128, 128, image[:, :, :40])

# %% [markdown]
# Define a 3D CNN

# %%
def get_model(width=128, height=128, depth=64):
    """Build a 3D convolutional neural network model."""

    inputs = keras.Input((width, height, depth, 1))

    x = layers.Conv3D(filters=64, kernel_size=3, activation="relu")(inputs)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=64, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=128, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv3D(filters=256, kernel_size=3, activation="relu")(x)
    x = layers.MaxPool3D(pool_size=2)(x)
    x = layers.BatchNormalization()(x)

    x = layers.GlobalAveragePooling3D()(x)
    x = layers.Dense(units=512, activation="relu")(x)
    x = layers.Dropout(0.3)(x)

    outputs = layers.Dense(units=1, activation="sigmoid")(x)

    # Define the model.
    model = keras.Model(inputs, outputs, name="3dcnn")
    return model


# Build model.
model = get_model(width=128, height=128, depth=64)
model.summary()
# Out:
# Model: "3dcnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 128, 128, 64, 1   0
#                              )]
#
#  conv3d_4 (Conv3D)           (None, 126, 126, 62, 64   1792
#                              )
#
#  max_pooling3d_4 (MaxPoolin  (None, 63, 63, 31, 64)    0
#  g3D)
#
#  batch_normalization_4 (Bat  (None, 63, 63, 31, 64)    256
#  chNormalization)
#
#  conv3d_5 (Conv3D)           (None, 61, 61, 29, 64)    110656
#
#  max_pooling3d_5 (MaxPoolin  (None, 30, 30, 14, 64)    0
#  g3D)
#
#  batch_normalization_5 (Bat  (None, 30, 30, 14, 64)    256
#  chNormalization)
#
#  conv3d_6 (Conv3D)           (None, 28, 28, 12, 128)   221312
#
#  max_pooling3d_6 (MaxPoolin  (None, 14, 14, 6, 128)    0
#  g3D)
#
#  batch_normalization_6 (Bat  (None, 14, 14, 6, 128)    512
#  chNormalization)
#
#  conv3d_7 (Conv3D)           (None, 12, 12, 4, 256)    884992
#
#  max_pooling3d_7 (MaxPoolin  (None, 6, 6, 2, 256)      0
#  g3D)
#
#  batch_normalization_7 (Bat  (None, 6, 6, 2, 256)      1024
#  chNormalization)
#
#  global_average_pooling3d_1  (None, 256)               0
#   (GlobalAveragePooling3D)
#
#  dense_2 (Dense)             (None, 512)               131584
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 1352897 (5.16 MB)
# Trainable params: 1351873 (5.16 MB)
# Non-trainable params: 1024 (4.00 KB)
# _________________________________________________________________

# %% [markdown]
# Train Model

# %%
# Compile model.
initial_learning_rate = 0.0001
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=100000, decay_rate=0.96, staircase=True
)
model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=lr_schedule),
    metrics=["acc"],
    run_eagerly=True,
)

# Define callbacks.
checkpoint_cb = keras.callbacks.ModelCheckpoint(
    "3d_image_classification.keras", save_best_only=True
)
early_stopping_cb = keras.callbacks.EarlyStopping(monitor="val_acc", patience=15)

# Train the model, doing validation at the end of each epoch
epochs = 100
model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=epochs,
    shuffle=True,
    verbose=2,
    callbacks=[checkpoint_cb, early_stopping_cb],
)
# Out:
# Epoch 1/100
# 70/70 - 73s - loss: 0.4606 - acc: 0.7643 - val_loss: 0.9697 - val_acc: 0.5333 - 73s/epoch - 1s/step
# Epoch 2/100
# 70/70 - 30s - loss: 0.5053 - acc: 0.7643 - val_loss: 0.6076 - val_acc: 0.6833 - 30s/epoch - 434ms/step
# Epoch 3/100
# 70/70 - 31s - loss: 0.4999 - acc: 0.7643 - val_loss: 0.9875 - val_acc: 0.5500 - 31s/epoch - 446ms/step
# Epoch 4/100
# 70/70 - 32s - loss: 0.4900 - acc: 0.7643 - val_loss: 0.5965 - val_acc: 0.6500 - 32s/epoch - 457ms/step
# Epoch 5/100
# 70/70 - 29s - loss: 0.4490 - acc: 0.8214 - val_loss: 0.7493 - val_acc: 0.5833 - 29s/epoch - 420ms/step
# Epoch 6/100
# 70/70 - 31s - loss: 0.4288 - acc: 0.7786 - val_loss: 0.6019 - val_acc: 0.6333 - 31s/epoch - 449ms/step
# Epoch 7/100
# 70/70 - 31s - loss: 0.4290 - acc: 0.7857 - val_loss: 1.8358 - val_acc: 0.5333 - 31s/epoch - 437ms/step
# Epoch 8/100
# 70/70 - 32s - loss: 0.3811 - acc: 0.8286 - val_loss: 2.0979 - val_acc: 0.5333 - 32s/epoch - 453ms/step
# Epoch 9/100
# 70/70 - 29s - loss: 0.3826 - acc: 0.8786 - val_loss: 1.3609 - val_acc: 0.5500 - 29s/epoch - 421ms/step
# Epoch 10/100
# 70/70 - 30s - loss: 0.4175 - acc: 0.8143 - val_loss: 0.9059 - val_acc: 0.6167 - 30s/epoch - 430ms/step
# Epoch 11/100
# 70/70 - 30s - loss: 0.3818 - acc: 0.8429 - val_loss: 0.6518 - val_acc: 0.6000 - 30s/epoch - 424ms/step
# Epoch 12/100
# 70/70 - 31s - loss: 0.3634 - acc: 0.8214 - val_loss: 0.8195 - val_acc: 0.6333 - 31s/epoch - 439ms/step
# Epoch 13/100
# 70/70 - 30s - loss: 0.4339 - acc: 0.7643 - val_loss: 0.9226 - val_acc: 0.6500 - 30s/epoch - 428ms/step
# Epoch 14/100
# 70/70 - 30s - loss: 0.3384 - acc: 0.8786 - val_loss: 0.6589 - val_acc: 0.6500 - 30s/epoch - 433ms/step
# Epoch 15/100
# 70/70 - 31s - loss: 0.4416 - acc: 0.7929 - val_loss: 0.5339 - val_acc: 0.7500 - 31s/epoch - 436ms/step
# Epoch 16/100
# 70/70 - 30s - loss: 0.3543 - acc: 0.8357 - val_loss: 0.6471 - val_acc: 0.6333 - 30s/epoch - 434ms/step
# Epoch 17/100
# 70/70 - 30s - loss: 0.3906 - acc: 0.8214 - val_loss: 1.2623 - val_acc: 0.5500 - 30s/epoch - 434ms/step
# Epoch 18/100
# 70/70 - 30s - loss: 0.3483 - acc: 0.8429 - val_loss: 1.2276 - val_acc: 0.5833 - 30s/epoch - 434ms/step
# Epoch 19/100
# 70/70 - 30s - loss: 0.3292 - acc: 0.8643 - val_loss: 0.6574 - val_acc: 0.6833 - 30s/epoch - 421ms/step
# Epoch 20/100
# 70/70 - 30s - loss: 0.3951 - acc: 0.8071 - val_loss: 0.7463 - val_acc: 0.6500 - 30s/epoch - 433ms/step
# Epoch 21/100
# 70/70 - 30s - loss: 0.4058 - acc: 0.8000 - val_loss: 0.7795 - val_acc: 0.6000 - 30s/epoch - 430ms/step
# Epoch 22/100
# 70/70 - 30s - loss: 0.3782 - acc: 0.8214 - val_loss: 1.4242 - val_acc: 0.5667 - 30s/epoch - 434ms/step
# Epoch 23/100
# 70/70 - 31s - loss: 0.3193 - acc: 0.8429 - val_loss: 0.7977 - val_acc: 0.6667 - 31s/epoch - 439ms/step
# Epoch 24/100
# 70/70 - 29s - loss: 0.2983 - acc: 0.8714 - val_loss: 0.7790 - val_acc: 0.7000 - 29s/epoch - 421ms/step
# Epoch 25/100
# 70/70 - 30s - loss: 0.3127 - acc: 0.8357 - val_loss: 2.3674 - val_acc: 0.5167 - 30s/epoch - 430ms/step
# Epoch 26/100
# 70/70 - 29s - loss: 0.3304 - acc: 0.8500 - val_loss: 0.7157 - val_acc: 0.6833 - 29s/epoch - 420ms/step
# Epoch 27/100
# 70/70 - 29s - loss: 0.3143 - acc: 0.8643 - val_loss: 0.8924 - val_acc: 0.6667 - 29s/epoch - 420ms/step
# Epoch 28/100
# 70/70 - 30s - loss: 0.2824 - acc: 0.9000 - val_loss: 0.6214 - val_acc: 0.6667 - 30s/epoch - 432ms/step
# Epoch 29/100
# 70/70 - 30s - loss: 0.2699 - acc: 0.8857 - val_loss: 0.7692 - val_acc: 0.6333 - 30s/epoch - 432ms/step
# Epoch 30/100
# 70/70 - 30s - loss: 0.2867 - acc: 0.8714 - val_loss: 0.6981 - val_acc: 0.7167 - 30s/epoch - 432ms/step

# %%
fig, ax =plt.subplots(1, 2, figsize=(20, 3))
ax = ax.ravel()

for i, metric in enumerate(["acc", "loss"]):
  ax[i].plot(model.history.history[metric])
  ax[i].plot(model.history.history["val_" + metric])
  ax[i].set_title("Model {}".format(metric))
  ax[i].set_xlabel("epochs")
  ax[i].set_ylabel(metric)
  ax[i].legend({"train", "val"})

# %% [markdown]
# Make Predictions on a Single CT Scan

# %%
# Load best weights.
model.load_weights("3d_image_classification.keras")
prediction = model.predict(np.expand_dims(x_val[0], axis=0))[0]
scores = [1 - prediction[0], prediction[0]]

class_names = ["normal", "abnormal"]
for score, name in zip(scores, class_names):
    print(
        "This model is %.2f percent confident that CT scan is %s"
        % ((100 * score), name)
    )
# Out:
# 1/1 [==============================] - 0s 30ms/step
# This model is 48.59 percent confident that CT scan is normal
# This model is 51.41 percent confident that CT scan is abnormal
